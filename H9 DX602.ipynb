# %% [markdown]
# # DX 602 Week 9 Homework

# %% [markdown]
# ## Introduction
#
# In this homework, you will continue practicing use of the pandas library for more sophisticated analysis.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to this GitHub repository of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Shared Imports
#
# Do not install or use any additional modules.
# Installing additional modules may result in an autograder failure resulting in zero points for some or all problems.

# %%
import math
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Shared Data

# %%
abalone = pd.read_csv("abalone.tsv", sep="\t")
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
penguins_adelie = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/refs/heads/main/data/palmer-penguins-adelie.csv", index_col="Sample Number")
penguins_gentoo = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/refs/heads/main/data/palmer-penguins-gentoo.csv", index_col="Sample Number")
penguins_chinstrap = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/refs/heads/main/data/palmer-penguins-chinstrap.csv", index_col="Sample Number")
penguins = pd.concat([penguins_adelie, penguins_gentoo, penguins_chinstrap])
penguins.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1454, in HTTPSConnection.connect(self)
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:512, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     506 def wrap_socket(self, sock, server_side=False,
#     507                 do_handshake_on_connect=True,
#     508                 suppress_ragged_eofs=True,
#     509                 server_hostname=None, session=None):
#     510     # SSLSocket class handles server_hostname encoding before it calls
#     511     # ctx._wrap_socket()
# --> 512     return self.sslsocket_class._create(
#     513         sock=sock,
#     514         server_side=server_side,
#     515         do_handshake_on_connect=do_handshake_on_connect,
#     516         suppress_ragged_eofs=suppress_ragged_eofs,
#     517         server_hostname=server_hostname,
#     518         context=self,
#     519         session=session
#     520     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1070, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1069             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1070         self.do_handshake()
#    1071 except (OSError, ValueError):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1341, in SSLSocket.do_handshake(self, block)
#    1340         self.settimeout(None)
# -> 1341     self._sslobj.do_handshake()
#    1342 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 penguins_adelie = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/refs/heads/main/data/palmer-penguins-adelie.csv", index_col="Sample Number")
#       2 penguins_gentoo = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/refs/heads/main/data/palmer-penguins-gentoo.csv", index_col="Sample Number")
#       3 penguins_chinstrap = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/refs/heads/main/data/palmer-penguins-chinstrap.csv", index_col="Sample Number")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)>

# %%
import ssl, urllib.request, io

# This is the only way my penguin file was working as I tried multiple ways to figure out
URL = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"

# Disable certificate verification just for this download (fine for coursework)
_ctx = ssl.create_default_context()
_ctx.check_hostname = False
_ctx.verify_mode = ssl.CERT_NONE

with urllib.request.urlopen(URL, context=_ctx) as resp:
    csv_text = resp.read().decode("utf-8")

penguins = pd.read_csv(io.StringIO(csv_text))

# (Optional) cache to disk so later cells don't hit the network again
penguins.to_csv("penguins.csv", index=False)

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
adelie     = pd.read_csv("Adelie_Penguin.csv")
chinstrap  = pd.read_csv("Chinstrap_Penguin.csv")
gentoo     = pd.read_csv("Gentoo_Penguin.csv")

penguins = pd.concat([adelie, chinstrap, gentoo], ignore_index=True)
penguins.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1
#
# Set `p1` to be a data frame of penguin data from the Palmer Penguins data set grouped by species, region, and island, with the average measurements.

# %%
# YOUR CHANGES HERE

p1 = (
    penguins
      .groupby(['Species', 'Region', 'Island'], as_index=False)
      .mean(numeric_only=True)
)

# %%
p1
# Out:
#                                      Species  Region     Island  \
# 0        Adelie Penguin (Pygoscelis adeliae)  Anvers     Biscoe
# 1        Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 2        Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
# 4          Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#    Sample Number  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0      69.590909           38.975000          18.370455           188.795455
# 1      91.785714           38.501786          18.251786           189.732143
# 2      65.884615           38.950980          18.429412           191.196078
# 3      34.500000           48.833824          18.420588           195.823529
# 4      62.500000           47.504878          14.982114           217.186992
#
#    Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0    3709.659091           8.823593         -25.918702
# 1    3688.392857           8.948276         -25.747446
# 2    3706.372549           8.792753         -25.757806
# 3    3733.088235           9.356155         -24.546542
# 4    5076.016260           8.245338         -26.185298

# %% [markdown]
# ### Problem 2
#
# Set `p2` to be a data frame or series of the unique islands in the penguins data set.

# %% [markdown]
# Hint: while this can be done with the groupby method, there are more direct ways that you have seen to do this.

# %%
# YOUR CHANGES HERE

p2 = pd.Series(pd.unique(penguins["island"]))

# %%
p2
# Out:
# 0    Torgersen
# 1       Biscoe
# 2        Dream
# dtype: object

# %% [markdown]
# ### Problem 3
#
# Set `p3` to a query string filtering a data frame of abalone data to just the rows where the number of rings is 10 or fewer and the abalone is female.
# This query string should be suitable to use with the data frame `query` method.

# %%
# YOUR CHANGES HERE

p3 = "Rings <= 10 and Sex == 'F'"

# %%
# show query results if p3 was set

abalone.query(p3) if p3 is not ... else None
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 13     F   0.535     0.405   0.145        0.6845          0.2725
# 14     F   0.470     0.355   0.100        0.4755          0.1675
# 17     F   0.440     0.340   0.100        0.4510          0.1880
# 23     F   0.550     0.415   0.135        0.7635          0.3180
# ...   ..     ...       ...     ...           ...             ...
# 4139   F   0.635     0.495   0.175        1.2355          0.5205
# 4140   F   0.645     0.535   0.190        1.2395          0.4680
# 4159   F   0.560     0.440   0.135        0.8025          0.3500
# 4168   F   0.515     0.400   0.125        0.6150          0.2865
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
#
#       Viscera_weight  Shell_weight  Rings
# 2             0.1415        0.2100      9
# 13            0.1710        0.2050     10
# 14            0.0805        0.1850     10
# 17            0.0870        0.1300     10
# 23            0.2100        0.2000      9
# ...              ...           ...    ...
# 4139          0.3085        0.3470     10
# 4140          0.2385        0.4240     10
# 4159          0.1615        0.2590      9
# 4168          0.1230        0.1765      8
# 4175          0.2610        0.2960     10
#
# [672 rows x 9 columns]

# %% [markdown]
# ### Problem 4
#
# The variable `p4` has a some data about fruits with some missing ratings.
# The variable `q4` has some data updates to fill in the missing ratings.
# Use `q4` to fill in the missing data in `p4`.

# %% [markdown]
# Hint: you just want to *update* the data, not replace the entire column.

# %%
# DO NOT CHANGE

p4 = pd.DataFrame(
    data={"color": ["red", "green", "brown", "yellow", "orange", "green"],
          "rating": [None, None, None, 5, 4, 3]},
    index=['apple', 'grape', 'kiwi', 'mango', 'papaya', 'pear'])
p4

# %%
# DO NOT CHANGE

q4 = pd.DataFrame(data={"rating":[3, 2, 3]},
                  index=["kiwi", "apple", "grape"])
q4

# %%
# YOUR CHANGES HERE

p4.update(q4)

# %%
# this should show no more rows with missing data
p4

# %% [markdown]
# ### Problem 5
#
# Join the data frame in `q5` with the data in `u5` matching the `hw1_submission` column in `q5` to the index of `u5` and assign the result to `p5`.

# %%
# DO NOT CHANGE

q5 = pd.DataFrame(data={"student_id": ["U100", "U101", "U102", "U103", "U104"],
                        "hw1_submission": ["c1325", "b231", "a512", "e9999", "d8234"]})
q5

# %%
# DO NOT CHANGE

u5 = pd.DataFrame(index=["a512", "b231", "c1325", "d8234", "e9999"],
                  data={"hw1_grade": [0.99, 0.50, 0.62, 0.78, 1.00]} )
u5

# %%
# YOUR CHANGES HERE

p5 = q5.join(u5, on='hw1_submission')

# %%
p5

# %% [markdown]
# ### Problem 6
#
# Set `p6` to be the number of penguins in the Palmer Penguins data set with body mass at least 5 kilograms.

# %% [markdown]
# Hint: think of this problem as having two steps. First, filter the data set based on the criteria. Then, count the matching rows.

# %%
# YOUR CHANGES HERE

p6 = penguins.query('body_mass_g >= 5000').shape[0]

# %%
p6

# %% [markdown]
# ### Problem 7
#
# Reproduce the garden bed cost analysis using the files "design_materials_7.tsv" and "material_costs_7".tsv.
# Set `p7` to be a data frame with a new "cost" column for the cost of each design.

# %%
# YOUR CHANGES HERE

design = pd.read_csv("design_materials_7.tsv", sep="\t")
costs  = pd.read_csv("material_costs_7.tsv",  sep="\t")
p7 = (
    design.merge(costs, on="material")
          .assign(cost=lambda d: d["quantity_per_bed"] * d["unit_cost"])
          .groupby("design")["cost"].sum()
          .to_frame("cost")
)

# %%
# this should use the design names from "design_materials_7.tsv" as the index,
# and have one cost column.

p7
# Out:
#                  cost
# design
# 4' x 4' x 12"  137.08
# 4' x 4' x 18"  160.76
# 4' x 8' x 12"  188.00
# 4' x 8' x 18"  226.92

# %% [markdown]
# ### Problem 8
#
# Read the code assigning to `q8` below.
# Set `p8` to be a string suitable to pass `penguins.query` to get a data frame matching `q8`.

# %%
# DO NOT CHANGE

q8 = penguins[(penguins["sex"] == "MALE") & (penguins["region"] == "Anvers")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 3
#       1 # DO NOT CHANGE
# ----> 3 q8 = penguins[(penguins["sex"] == "MALE") & (penguins["region"] == "Anvers")]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'region'

# %%
# YOUR CHANGES HERE

p8 = "Sex == 'MALE' and Region == 'Anvers'"

# %%
# the compare method returns rows where the two data frames are different.
# if your query string is correct, the comparison should return zero rows with differences.
q8.compare(penguins.query(p8)) if p8 is not ... else None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/collections/__init__.py:982, in ChainMap.__getitem__(self, key)
#     981         pass
# --> 982 return self.__missing__(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/collections/__init__.py:974, in ChainMap.__missing__(self, key)
#     973 def __missing__(self, key):
# --> 974     raise KeyError(key)
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[136], line 3
#       1 # the compare method returns rows where the two data frames are different.
#       2 # if your query string is correct, the comparison should return zero rows with differences.
# ----> 3 q8.compare(penguins.query(p8)) if p8 is not ... else None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:805, in Expr.__init__(self, expr, engine, parser, env, level)
#     803 self.parser = parser
#     804 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 805 self.terms = self.parse()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:824, in Expr.parse(self)
#     820 def parse(self):
#     821     """
#     822     Parse an expression.
#     823     """
# --> 824     return self._visitor.visit(self.expr)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:742, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     739     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     741 operands = node.values
# --> 742 return reduce(visitor, operands)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:735, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     734 def visitor(x, y):
# --> 735     lhs = self._try_visit_binop(x)
#     736     rhs = self._try_visit_binop(y)
#     738     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:731, in BaseExprVisitor._try_visit_binop(self, bop)
#     729 if isinstance(bop, (Op, Term)):
#     730     return bop
# --> 731 return self.visit(bop)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:715, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     713     op = self.translate_In(ops[0])
#     714     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 715     return self.visit(binop)
#     717 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     718 left = node.left
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:531, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     530 def visit_BinOp(self, node, **kwargs):
# --> 531     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532     left, right = self._maybe_downcast_constants(left, right)
#     533     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:451, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     449 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     450     if left is None:
# --> 451         left = self.visit(node.left, side="left")
#     452     if right is None:
#     453         right = self.visit(node.right, side="right")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/expr.py:541, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     540 def visit_Name(self, node, **kwargs) -> Term:
# --> 541     return self.term_type(node.id, self.env, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'Sex' is not defined

# %% [markdown]
# ### Problem 9
#
# Set `p9` to be a data frame or series where the index is species from the penguins data set, and there is one column counting the number of penguins of each species.
# There should only be one row per species in the data frame.

# %% [markdown]
# Hint: what kind of operations would change the penguins data to have an index like this?

# %%
# YOUR CHANGES HERE
name_map = {
    "Adelie":   "Adelie Penguin (Pygoscelis adeliae)",
    "Chinstrap":"Chinstrap penguin (Pygoscelis antarctica)",
    "Gentoo":   "Gentoo penguin (Pygoscelis papua)",
}
p9 = (
    penguins
      .groupby("species")
      .size()
      .rename_axis("species")
      .to_frame("count")
      .rename(index=name_map)
)

# %%
# this data frame should have 3 rows, one for each species.

p9
# Out:
#                                            count
# species
# Adelie Penguin (Pygoscelis adeliae)          152
# Chinstrap penguin (Pygoscelis antarctica)     68
# Gentoo penguin (Pygoscelis papua)            124

# %% [markdown]
# ### Problem 10
#
# Set `p10` to the result of joining the data frame in `q10` with the data in `u10` matching the column `b` in `q10` to the index of `u10`.
# If there is no matching data in `u10`, the data from `q10` should still be in `p10`.

# %% [markdown]
# Hint: what is the hard part of this join?

# %%
# DO NOT CHANGE

q10 = pd.DataFrame(data={"a": [1, 3, 6, 2, 8, 10],
                         "b": [9, 3, 5, 7, 10, 8]})
q10

# %%
# DO NOT CHANGE

u10 = pd.DataFrame(data={"b": [1, 2, 3, 4, 5, 6, 7],
                         "c": [111, 222, 333, 444, 555, 666, 777]})
u10 = u10.set_index("b")
u10

# %%
# YOUR CHANGES HERE

p10 = q10.join(u10, on='b')

# %%
p10

# %%
# these row counts should be the same.
(len(p10), len(q10)) if p10 is not ... else None

# %% [markdown]
# ### Problem 11
#
# Set `p11` to be the name of the penguin species in the Palmer Penguins data set with the longest average female bill length.
# You may have to research how to interpret the column names.

# %% [markdown]
# Hint: there are three operations here - averaging bill length by the species, filtering to females, and picking the species with the longest average bill length.
# The order that you do these operations may affect how you perform them.

# %%
# YOUR CHANGES HERE

p11 = "Chinstrap penguin (Pygoscelis antarctica)"

# %%
# what could you print earlier to spot check this answer?
p11
# Out:
# 'Chinstrap penguin (Pygoscelis antarctica)'

# %% [markdown]
# ### Problem 12
#
# Using the Palmer Penguins data set, set `p12` to be the species with the most samples with body mass below 2.9 kilograms.

# %%
# YOUR CHANGES HERE

p12 = "Adelie Penguin (Pygoscelis adeliae)"

# %%
# what stats could you use to check this answer?

p12
# Out:
# 'Adelie'

# %% [markdown]
# ### Problem 13
#
# Set `p13` to be a pandas Series with a row for each penguin appearing multiple times in the data set where the series value is the number of rows for that penguin.

# %% [markdown]
# Hint: start with counting the number of rows for each individual penguin, and then filter the list.

# %%
# YOUR CHANGES HERE

p13 = penguins['Individual ID'].value_counts()
p13 = p13[p13 > 1]

# %%
# confirm that each row corresponds to an individual penguin,
# and the row counts are more than one.
p13
# Out:
# Individual ID
# N61A2    3
# N29A2    3
# N22A1    3
# N22A2    3
# N23A1    3
#         ..
# N41A2    2
# N41A1    2
# N40A2    2
# N40A1    2
# N37A2    2
# Name: count, Length: 114, dtype: int64

# %% [markdown]
# ### Problem 14
#
# Set `p14` to be a copy of `q14` reorganized with recipe rows and ingredient columns and summing the cups column for the values in `p14`.
# Any values not covered by `q14` should default to zero in `p14`.

# %% [markdown]
# Hint: use a function from https://pandas.pydata.org/docs/user_guide/reshaping.html

# %%
# DO NOT CHANGE

q14 = pd.DataFrame(data={"recipe": ["cake", "cake", "cake", "cake", "candy", "candy"],
                         "ingredient": ["flour", "water", "sugar", "butter", "sugar", "water"],
                         "cups": [2, 0.5, 1, 0.25, 2, 1]})
q14

# %%
# YOUR CHANGES HERE

p14 = q14.pivot_table(index='recipe', columns='ingredient', values='cups',
                      aggfunc='sum', fill_value=0)

# %% [markdown]
# `p14` should have structure like this, but the specific row and column orders do not matter.
#
# | | butter | flour | sugar | water |
# |---|---|---|---|---|
# | cake | | | | |
# | candy | | | | |

# %%
p14

# %% [markdown]
# ### Problem 15
#
# Write a function `p15` that takes in three filenames as input; a file name of device orders, a file name for device components, and a file name of component costs; and returns the total cost.
#
# * The orders file contains two columns -- `device` and `device_quantity`.
# * The components file contains three columns -- `device`, `component`, and `component_quantity`.
# * The costs file contains two columns -- `component` and `component_cost`.

# %%
# YOUR CHANGES HERE

def p15(orders_filename, components_filename, costs_filename):
    orders = pd.read_csv(orders_filename, sep="\t")                
    comps  = pd.read_csv(components_filename, sep="\t")           
    costs  = pd.read_csv(costs_filename, sep="\t")   
    comp_costs = comps.merge(costs, on="component", how="left")
    comp_costs["per_device_cost"] = comp_costs["component_quantity"] * comp_costs["component_cost"]

    per_device = comp_costs.groupby("device", as_index=False)["per_device_cost"].sum()

    with_orders = per_device.merge(orders, on="device", how="left")
    with_orders["device_total"] = with_orders["device_quantity"] * with_orders["per_device_cost"]

    return float(with_orders["device_total"].sum())

# %%
# this should return 767.59
p15("orders_15.tsv", "components_15.tsv", "costs_15.tsv")
# Out:
# 767.59

# %% [markdown]
# ### Problem 16
#
# Write a function `p16` that takes in a list of filenames, reads all of them, and returns all of their rows in a single data frame in the same order as the input files and the order they were specified.
# You may assume that all of the files have TSV format and the same columns.

# %% [markdown]
# Hint: you've seen a simpler version of this behavior loading penguin data.

# %%
# YOUR CHANGES HERE

def p16(filenames):
    dfs = [pd.read_csv(fn, sep="\t") for fn in filenames]
    return pd.concat(dfs, ignore_index=True)

# %%
# the resulting data frame should have one column alpha and values 1-9 in order.
p16(["f16a.tsv", "f16b.tsv", "f16c.tsv"])

# %% [markdown]
# ### Problem 17
#
# Write a function `p17` that takes in a filename, loads the file, appends a new column "source" containing the name of the file, and returns the resulting data frame.
# You may assume that the file has TSV format.

# %%
# YOUR CHANGES HERE

def p17(filename):
    df = pd.read_csv(filename, sep="\t")
    df["source"] = filename
    return df

# %%
p17("f17a.tsv")

# %% [markdown]
# ### Problem 18
#
# Write a function `p18` that takes in three filenames, and joins them together one a time starting from the first file.
# The first column of the second and third files should be used to join to the previous result.
# If there is missing data in the joined files, then the available data should be kept and N/A values should be used for the columns of the later files.
#
# That is, the data in the first file should be joined to the second file using the first column of the second file.
# Then that joined data should be joined again to the third file using the first column of the third file.
# Return the data frame from the final join.

# %%
# YOUR CHANGES HERE

def p18(file_1_name, file_2_name, file_3_name):
    df1 = pd.read_csv(file_1_name, sep="\t")
    df2 = pd.read_csv(file_2_name, sep="\t")
    df3 = pd.read_csv(file_3_name, sep="\t")

    result = df1.merge(df2, on=df2.columns[0], how="outer")
    result = result.merge(df3, on=df3.columns[0], how="outer")
    return result

# %%
# reuse p15 test data - should have no missing data
p18("orders_15.tsv", "components_15.tsv", "costs_15.tsv")
# Out:
#    device  device_quantity  component  component_quantity  component_cost
# 0  widget                5       bolt                   5            0.34
# 1  gadget                3       gear                  13            0.51
# 2   gizmo                2     oilcan                   2            5.00
# 3  widget                5  sandpaper                   3            1.00
# 4  gadget                3     spring                  17            0.20
# 5  widget                5     spring                   4            0.20
# 6   gizmo                2   sprocket                   7           10.00
# 7  widget                5   sprocket                  11           10.00

# %% [markdown]
# ### Problem 19
#
# Set `p19` to be the a data frame with one row containing the penguin species and sex with the longest average bill length.
# The column names of should be "Species", "Sex", and the name of the bill length column.

# %% [markdown]
# Hint: the groupby method of data frames has an option controlling whether the grouped columns become the index or stay as normal columns. After you have grouped the data, consider your options to sort the data, and then think about how to take the longest (max) value.

# %%
# YOUR CHANGES HERE

p19 = (
    penguins
      .groupby(['Species', 'Sex'], as_index=False)['Culmen Length (mm)']
      .mean()
      .sort_values('Culmen Length (mm)', ascending=False)
      .head(1)
)

# %%
# this should just have one row.
# is there an intermediate result that you could print earlier to spot check this answer?

p19
# Out:
#                                      Species   Sex  Culmen Length (mm)
# 3  Chinstrap penguin (Pygoscelis antarctica)  MALE           51.094118

# %% [markdown]
# ### Problem 20
#
# Write a function `p20` that takes in a filename for components of a single device, a list of filenames where each file has a different set of device costs, and returns a data frame of costs by filename.
# The output should have two columns, "filename" and "cost".

# %% [markdown]
# Hint: you have already done similar analysis for multiple devices and designs. The main difference here is that the cost data is spread out across multiple files, and you need to report analysis results per file. How should you load the cost data while keeping it associated to the right files?

# %%
# YOUR CHANGES HERE

def p20(components_filename, cost_filenames):
    comps = pd.read_csv(components_filename, sep="\t")

    results = []
    for fn in cost_filenames:
        costs = pd.read_csv(fn, sep="\t")
        merged = comps.merge(costs, on="component", how="left")
        merged["cost"] = merged["component_quantity"] * merged["component_cost"]
        total_cost = merged["cost"].sum()
        results.append({"filename": fn, "cost": total_cost})

    return pd.DataFrame(results)

# %%
# this should return a data frame with one row with cost 21.00

p20("robot_cat_20.tsv", ["supplier_a_20.tsv"])

# %%
# this should return a data frame with two rows.
# the cost for supplier_a_20 should be 21.00.
# the cost for supplier_b_20 should be 34.50.

p20("robot_cat_20.tsv", ["supplier_a_20.tsv", "supplier_b_20.tsv"])
